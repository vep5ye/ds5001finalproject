# %% [markdown]
# # Final Project Notebook
#
# DS 5001 Text as Data

# %% [markdown]
# # Metadata
#
# - Full Name: Tiandra Threat
# - Userid: vep5ye
# - GitHub Repo URL: https://github.com/vep5ye/ds5001finalproject
# - UVA Box URL: https://virginia.app.box.com/collection/37165060558

# %% [markdown]
# # Overview
#
# The goal of the final project is for you to create a **digital analytical edition** of a corpus using the tools, practices, and perspectives you’ve learning in this course. You will select a corpus that has already been digitized and transcribed, parse that into an F-compliant set of tables, and then generate and visualize the results of a series of fitted models. You will also draw some tentative conclusions regarding the linguistic, cultural, psychological, or historical features represented by your corpus. The point of the exercise is to have you work with a corpus through the entire pipeline from ingestion to interpretation.
#
# Specifically, you will acquire a collection of long-form texts and perform the following operations:
#
# - **Convert** the collection from their source formats (F0) into a set of tables that conform to the Standard Text Analytic Data Model (F2).
# - **Annotate** these tables with statistical and linguistic features using NLP libraries such as NLTK (F3).
# - **Produce** a vector representation of the corpus to generate TFIDF values to add to the TOKEN (aka CORPUS) and VOCAB tables (F4).
# - **Model** the annotated and vectorized model with tables and features derived from the application of unsupervised methods, including PCA, LDA, and word2vec (F5).
# - **Explore** your results using statistical and visual methods.
# - **Present** conclusions about patterns observed in the corpus by means of these operations.
#
# When you are finished, you will make the results of your work available in GitHub (for code) and UVA Box (for data). You will submit to Gradescope (via Canvas) a PDF version of a Jupyter notebook that contains the information listed below.
#
# # Some Details
#
# - Please fill out your answers in each task below by editing the markdown cell.
# - Replace text that asks you to insert something with the thing, i.e. replace `(INSERT IMAGE HERE)` with an image element, e.g. `![](image.png)`.
# - For URLs, just paste the raw URL directly into the text area. Don't worry about providing link labels using `[label](link)`.
# - Please do not alter the structure of the document or cell, i.e. the bulleted lists.
# - You may add explanatory paragraphs below the bulleted lists.
# - Please name your tables as they are named in each task below.
# - Tasks are indicated by headers with point values in parentheses.

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Source Description (1)

# %% [markdown]
# Provide a brief description of your source material, including its provenance and content. Tell us where you found it and what kind of content it contains.
#
# - The primary source material used in this project is Jet Magazine, a weekly publication that ran from 1951 to 2014. Jet was a groundbreaking Black-owned magazine created for African American audiences during a time of significant social inequality. It covered a wide range of topics, including fashion, entertainment, current events, beauty, and culture.
#
# - For this analysis, I worked with 10 issues of Jet Magazine published between 1951 and 1978. The magazines were collected from the Internet Archive and downloaded individually in EPUB format. After downloading each file, I applied a parser to extract and structure the text for analysis.

# %% [markdown]
# ## Source Features (1)
#
# Add values for the following items. (Do this for all following bulleted lists.)
#
# - Source URL: https://archive.org/details/@aniyah_mcwilliams/lists/1/ds-5001%3A-final-project-data
# - UVA Box URL: https://virginia.app.box.com/collection/37165060558
# - Number of raw documents: 10
# - Total size of raw documents (e.g. in MB): 178 MB
# - File format(s), e.g. XML, plaintext, etc.: EPUB

# %% [markdown]
# ## Source Document Structure (1)
#
# Provide a brief description of the internal structure of each document. That, describe the typical elements found in document and their relation to each other. For example, a corpus of letters might be described as having a date, an addressee, a salutation, a set of content paragraphs, and closing. If they are various structures, state that.
#
# - Each magazine is made up of multiple short articles that focus on different events, trends, and topics across fashion, beauty, and politics. These articles are typically structured with a headline, a short introduction, a few body paragraphs, and a brief conclusion. Many of them also include images, though some are more text-heavy while others are more visual.
#
# - Due to the messy nature of the data, it was difficult to reliably separate the text into individual articles or match content to specific headlines. Because of this, the OHCO structure for this analysis was simplified to the magazine level and page number, rather than attempting to break the text down further by article.

# %% [markdown]
# # Parsed and Annotated Data
#
# Parse the raw data into the three core tables of your addition: the `LIB`, `CORPUS`, and `VOCAB` tables.
#
# These tables will be stored as CSV files with header rows.
#
# You may consider using `|` as a delimitter.
#
# Provide the following information for each.

# %% [markdown]
# ## LIB (2)
#
# The source documents the corpus comprises. These may be books, plays, newspaper articles, abstracts, blog posts, etc.
#
# Note that these are *not* documents in the sense used to describe a bag-of-words representation of a text, e.g. chapter.
#
# - UVA Box URL: https://virginia.box.com/s/egicjadnnyz3gbjp68zt8fjq46epkfuh
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/Cleaning%20and%20Derived%20Tables.ipynb
# - Delimitter: comma
# - Number of observations: 10
# - List of features, including at least three that may be used for model summarization (e.g. date, author, etc.):
#     - Date published
#     - Quarter published
#     - Length of magazine in characters
#     - Month published
#     - Length of magazine in characters
#     - Page numbers
#     - epub_id
# - Average length of each document in characters: 82871.1

# %% [markdown]
# ## CORPUS (2)
#
# The sequence of word tokens in the corpus, indexed by their location in the corpus and document structures.
#
# - UVA Box URL: https://virginia.box.com/s/uamh7wf9q8bek3f872z5g2ggpomjb9q0
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/Cleaning%20and%20Derived%20Tables.ipynb
# - Delimitter: comma
# - Number of observations Between (should be >= 500,000 and <= 2,000,000 observations.): 131,948
# - OHCO Structure (as delimitted column names):
#     - mag_id: represents the magazine id
#     - page_num: represents the page number
#     - token_num: represents the token number associated with the token
# - Columns (as delimitted column names, including `token_str`, `term_str`, `pos`, and `pos_group`):
#     - mag_id
#     - page_num
#     - token_num
#     - pos
#     - pos_group
#     - token_str
#     - term_str

# %% [markdown]
# ## VOCAB (2)
#
# The unique word types (terms) in the corpus.
#
# - UVA Box URL: https://virginia.box.com/s/883cy6a05thsj7jyyrzp0kiufbhkoqbx
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/Cleaning%20and%20Derived%20Tables.ipynb
# - Delimitter: comma
# - Number of observations: 16,287
# - Columns (as delimitted names, including `n`, `p`', `i`, `dfidf`, `porter_stem`, `max_pos` and `max_pos_group`, `stop`):
#     - term_str, n, n_chars, p, i, max_pos, max_pos_group, stop, stem_porter
# - Note: Your VOCAB may contain ngrams. If so, add a feature for `ngram_length`.
# - List the top 20 significant words in the corpus by DFIDF:
#     - shells
#     - springfield
#     - squad
#     - demonstrate
#     - demands
#     - delores
#     - delivery
#     - stabbed
#     - delicate
#     - stadium
#     - delaware
#     - deknight
#     - definitely
#     - standard
#     - defendant
#     - defeated
#     - defeat
#     - dedicated
#     - declined
#     - starred

# %% [markdown]
# # Derived Tables

# %% [markdown]
# ## BOW (3)
#
# A bag-of-words representation of the CORPUS.
#
# - UVA Box URL: https://virginia.box.com/s/01hoh8wcy0u7zr2340gxjg3fz8u7hldz
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/bow.ipynb
# - Delimitter: comma
# - Bag (expressed in terms of OHCO levels): mag_id
# - Number of observations: 39,538
# - Columns (as delimitted names, including `n`, `tfidf`): mag_id, term_str, n, tf, idf, tfidf

# %% [markdown]
# ## DTM (3)
#
# A represenation of the BOW as a sparse count matrix.
#
# - UVA Box URL: https://virginia.box.com/s/yvzei3px4md9u1gj0ylye6eqwib5odtw
# - UVA Box URL of BOW used to generate (if applicable): https://virginia.box.com/s/01hoh8wcy0u7zr2340gxjg3fz8u7hldz
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/dtm.ipynb
# - Delimitter: comma
# - Bag (expressed in terms of OHCO levels): mag_id

# %% [markdown]
# ## TFIDF (3)
#
# A Document-Term matrix with TFIDF values.
#
# - UVA Box URL: https://virginia.box.com/s/gx8o7zgqn27i23877cxb4wsuazynbwex
# - UVA Box URL of DTM or BOW used to create: https://virginia.box.com/s/yvzei3px4md9u1gj0ylye6eqwib5odtw
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/tfidf.ipynb
# - Delimitter: comma
# - Description of TFIDIF formula ($\LaTeX$ OK):
#     - np.log2(1 + DTM) * np.log2(N / DF)
#     - DTM: Document Term Matrix (referred to as DTCM in my code)
#     - N: Length of DTM
#     - DF: Document Frequency

# %% [markdown]
# ## Reduced and Normalized TFIDF_L2 (3)

# %% [markdown]
# A Document-Term matrix with L2 normalized TFIDF values.
#
# - UVA Box URL: https://virginia.box.com/s/720ngjsvakaomvlhq95p6qej8d1048wd
# - UVA Box URL of source TFIDF table: https://virginia.box.com/s/gx8o7zgqn27i23877cxb4wsuazynbwex
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/tfidf_l2.ipynb
# - Delimitter: comma
# - Number of features (i.e. significant words): 6,023
# - Principle of significant word selection: Significant words were selected based on their entropy (dh) values, which measure how informative a word is across the documents. I applied a threshold to filter out both very common words and noisy or less useful terms. The goal was to keep words that actually help differentiate the documents, while removing ones that don’t add much value. After that, the remaining words were used to create the L2 normalized TFIDF table.

# %% [markdown]
# # Models

# %% [markdown]
# ## PCA Components (4)
#
# - UVA Box URL: https://virginia.box.com/s/8dds1tu37jl2k9r2kq91bonakg1gmdmm
# - UVA Box URL of the source TFIDF_L2 table:
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/pca.ipynb
# - Delimitter: comma
# - Number of components: 3
# - Library used to generate: sklearn.decomposition
# - Top 5 positive terms for first component: blacks, benson, reggie, tito, granada
# - Top 5 negative terms for second component: diggs, bavasi, wills, tornado, edt

# %% [markdown]
# ## PCA DCM (4)
#
# The document-component matrix generated.
#
# - UVA Box URL: https://virginia.box.com/s/ysjgwvb2bb49q22hsa9rls1bozgdznyb
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/pca.ipynb
# - Delimitter: comma

# %% [markdown]
# ## PCA Loadings (4)
#
# The component-term matrix generated.
#
# - UVA Box URL: https://virginia.box.com/s/8dds1tu37jl2k9r2kq91bonakg1gmdmm
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/pca.ipynb
# - Delimitter: comma

# %% [markdown]
# ## PCA Visualization 1 (4)
#
# Include a scatterplot of documents in the space created by the first two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![](images/pcaloadings.png)
#
# ![](images/pcascatterplot.png)
#
# Briefly describe the nature of the polarity you see in the first component:
#
# - The first component shows a polarity between a small set of distinct, high-weight terms and the majority of words that cluster tightly around zero. A few words (like “blacks” and names) pull strongly in one direction, while most terms contribute very little, suggesting the component is capturing a narrow but meaningful distinction in the corpus rather than a broad theme.

# %% [markdown]
# ## PCA Visualization 2 (4)
#
# Include a scatterplot of documents in the space created by the second two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![](images/pcadocscatterplot.png)
#
# ![](images/pcaloadingsscatterplot.png)
#
# Briefly describe the nature of the polarity you see in the second component:
#
# - The second component shows a weaker polarity compared to the first, with most terms clustered tightly around zero and only a few spreading outward. This suggests the distinction captured here is more subtle, with small variations rather than a clear split. The documents also appear more mixed across this space, indicating that this component reflects less dominant patterns in the corpus.

# %% [markdown]
# ## LDA TOPIC (4)
#
# - UVA Box URL: https://virginia.box.com/s/w09udfmltal0nhiqmx8hg2dm8qjlkwsd
# - UVA Box URL of count matrix used to create: https://virginia.box.com/s/yvzei3px4md9u1gj0ylye6eqwib5odtw
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/lda.ipynb
# - Delimitter: comma
# - Libary used to compute: sklearn.decomposition
# - A description of any filtering, e.g. POS (Nouns and Verbs only): nouns only
# - Number of components: 5
# - Any other parameters used:
#   - stop_words='english' --> creating my own stop words did worse
#   - max_df=0.5 --> shows up in no more than 50% of the documents
#   - min_df=4 --> shows up in no less than 4 of the documents
# - Top 5 words and best-guess labels for topic five topics by mean document weight:
#   - T00: she, ruby, sam, minnie, february
#   - T01: astute, berlin, amused, asphalt, casket
#   - T02: casket, berlin, asphalt, amused, astute
#   - T03: casket, berlin, astute, asphalt, amused
#   - T04: to, in, and, of, the

# %% [markdown]
# ## LDA THETA (4)
#
# - UVA Box URL: https://virginia.box.com/s/a4hbao6j9lzgw4f0tax8f5dfx3atosgh
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/lda.ipynb
# - Delimitter: comma

# %% [markdown]
# ## LDA PHI (4)
#
# - UVA Box URL: https://virginia.box.com/s/gmph90h5zq4ogr749vgd1yi4fxpj7kkm
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/lda.ipynb
# - Delimitter: comma

# %% [markdown]
# ## LDA + PCA Visualization (4)
#
# Apply PCA to the THETA table and plot the topics in the space opened by the first two components.
#
# Size the points based on the mean document weight of each topic (using the THETA table).
#
# Color the points basd on a metadata feature from the LIB table.
#
# Provide a brief interpretation of what you see.
#
# ![](images/ldaviz.png)
#
# - One topic clearly dominates the space, showing up as a much larger point and positioned far from the others along PC0. This suggests that most documents are heavily weighted toward a single topic, while the remaining topics contribute very little and cluster near the origin. The lack of separation indicates that the model is not capturing distinct themes well, but instead is concentrated around one dominant pattern.

# %% [markdown]
# ## Sentiment VOCAB_SENT (4)
#
# Sentiment values associated with a subset of the VOCAB from a curated sentiment lexicon.
#
# - UVA Box URL: https://virginia.box.com/s/ix5t9smcp2d4ic2li6ux68qzs1w5p5rs
# - UVA Box URL for source lexicon: https://virginia.box.com/s/dcr5kz86xtha7s3e68u0u85ft6a8v02c
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/sentiment.ipynb
# - Delimitter: comma

# %% [markdown]
# ## Sentiment BOW_SENT (4)
#
# Sentiment values from VOCAB_SENT mapped onto BOW.
#
# - UVA Box URL: https://virginia.box.com/s/co1rlx28er92puog7ge8b2x4qso6chcd
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/sentiment.ipynb
# - Delimitter: comma

# %% [markdown]
# ## Sentiment DOC_SENT (4)
#
# Computed sentiment per bag computed from BOW_SENT.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/sentiment.ipynb
# - Delimitter: comma
# - Document bag expressed in terms of OHCO levels: mag_id

# %% [markdown]
# ## Sentiment Plot (4)
#
# Plot sentiment over some metric space, such as time.
#
# If you don't have a metric metadata features, plot sentiment over a feature of your choice.
#
# You may use a bar chart or a line graph.
#
# ![](images/sentiment.png)

# %% [markdown]
# ## VOCAB_W2V (4)
#
# A table of word2vec features associated with terms in the VOCAB table.
#
# - UVA Box URL: https://virginia.box.com/s/8q29bjszx4baibma8wahg4aubsb0drar
# - GitHub URL for notebook used to create: https://github.com/vep5ye/ds5001finalproject/blob/main/word2vec.ipynb
# - Delimitter: comma
# - Document bag expressed in terms of OHCO levels: mag_id
# - Number of features generated: 100
# - The library used to generate the embeddings: genism

# %% [markdown]
# ## Word2vec tSNE Plot (4)
#
# Plot word embedding featues in two-dimensions using t-SNE.
#
# Describe a cluster in the plot that captures your attention.
#
# ![](images/w2v.png)
#
# - One cluster that stands out is on the right side of the plot, where words like “segregation,” “racial,” “civil,” and “discrimination” appear close together. This cluster captures attention because the terms are clearly related to civil rights and social issues, suggesting that the model is grouping words based on shared context around race and inequality. It shows that Word2Vec is picking up on meaningful relationships in the corpus rather than just word frequency.

# %% [markdown]
# # Riffs
#
# Provde at least three visualizations that combine the preceding model data in interesting ways.
#
# These should provide insight into how features in the LIB table are related.
#
# The nature of this relationship is left open to you -- it may be correlation, or mutual information, or something less well defined.
#
# In doing so, consider the following visualization types:
#
# - Hierarchical cluster diagrams
# - Heatmaps
# - Scatter plots
# - KDE plots
# - Dispersion plots
# - t-SNE plots
# - etc.

# %% [markdown]
# ## Riff 1 (5)
#
# ![](images/riff1.png)
#
# - This plot shows how documents are positioned in the PCA space while also incorporating quarter and document length. The points are spread out across the space, which suggests that the documents are meaningfully differentiated based on their content. There is no clear clustering by quarter, which indicates that the themes in the magazines are not strongly separated by time. The variation in point size shows that longer documents do not consistently fall into one area, suggesting that document length does not drive the structure captured by PCA.

# %% [markdown]
# ## Riff 2 (5)
#
# ![](images/riff2.png)
#
# - This line graph shows a steady increase in sentiment from the 1st to the 4th quarter. The upward trend suggests that the overall tone of the magazines becomes more positive over time. The change is gradual at first but becomes more noticeable by the 3rd and 4th quarters, indicating a shift in the emotional content of the text.

# %% [markdown]
# ## Riff 3 (5)
#
# ![](images/riff3.png)
#
# - This heatmap shows that T04 dominates across all quarters, while the other topics have very little weight. This suggests that the LDA model is not effectively separating the corpus into distinct themes, but instead is concentrating most of the content into one broad topic. The only slight variation appears in the 1st quarter, where T00 has a bit more presence compared to the other quarters.

# %% [markdown]
# # Interpretation (4)
#
# Describe something interesting about your corpus that you discovered during the process of completing this assignment.
#
# At a minumum, use 250 words, but you may use more. You may also add images if you'd like.
#
# - One of the most interesting things I discovered about the corpus is how much the structure of the data influenced the results of the models. Going into this, I expected the models—especially LDA—to clearly separate the magazines into distinct themes like politics, entertainment, or fashion. However, that did not happen. Instead, one topic (T04) dominated almost every document, which showed that the model was not really capturing meaningful thematic differences. This made me realize that the issue was not necessarily with the model itself, but with how the text was structured and processed. Since the data could not be cleanly broken down into individual articles and was instead grouped at the magazine level, the model ended up learning a very broad, generalized representation of the text.
#
# - Another interesting observation came from the sentiment analysis. There was a clear upward trend in sentiment across the quarters, suggesting that the tone of the magazines became more positive over time. This was not something I expected going in, but it highlights how even a simple aggregation of sentiment scores can reveal patterns tied to time. It also made me think more critically about what sentiment actually represents in this context—whether it reflects genuine shifts in tone or just changes in the types of content being published.
#
# - Finally, the Word2Vec visualization stood out because it was one of the few places where clear, meaningful groupings emerged. Words related to civil rights and social issues appeared close together, showing that the model was able to capture deeper contextual relationships within the text. Overall, this project showed me that while some models struggle depending on data structure, others can still uncover meaningful patterns, and understanding the limitations of each approach is just as important as the results themselves.
